# %% [markdown]
# <a href="https://colab.research.google.com/github/pranithsai/AI-ML/blob/main/aiml_lab_exam_2303A54072_set5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
file_path = '/mnt/data/penguins_Clustering.csv'
data = pd.read_csv("/content/drive/MyDrive/penguins_Clustering.csv")

# %%
data = data.dropna()

# %%
features = ['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']
X = data[features]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans_3 = KMeans(n_clusters=3, random_state=42)
kmeans_3.fit(X_scaled)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
kmeans_4 = KMeans(n_clusters=4, random_state=42)
kmeans_4.fit(X_scaled)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
silhouette_3 = silhouette_score(X_scaled, kmeans_3.labels_)
silhouette_4 = silhouette_score(X_scaled, kmeans_4.labels_)

# %%
print(f"Silhouette Score for 3 Clusters: {silhouette_3}")
print(f"Silhouette Score for 4 Clusters: {silhouette_4}")
# Out:
# Silhouette Score for 3 Clusters: 0.49630047442464464
# Silhouette Score for 4 Clusters: 0.4746420543519823

# %%
K_range = range(1, 11)

# %%
wcss = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8, 5))
plt.plot(K_range, wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.xticks(K_range)
plt.show()
